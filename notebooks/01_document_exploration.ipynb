# %%
import sys, os
sys.path.append(os.path.abspath('..'))
from src.document_loader import DocumentLoader

loader = DocumentLoader('../data/documents')
documents = loader.load_all_documents()
print(f"Total Ingested Pages/Sections: {len(documents)}")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 3
#       1 import sys, os
#       2 sys.path.append(os.path.abspath('..'))
# ----> 3 from src.document_loader import DocumentLoader
#       4
#       5 loader = DocumentLoader('../data/documents')
#       6 documents = loader.load_all_documents()
#
# File ~/Documents/GitHub/Enterprise_Technical_Documentation_Assistant/src/__init__.py:7
#       1 """
#       2 Enterprise Technical Documentation Assistant RAG Package
#       3 =========================================================
#       4 Exports core RAG pipeline components and modules.
#       5 """
# ----> 7 from src.document_loader import DocumentLoader
#       8 from src.chunking import CodeAwareTextSplitter, TechnicalChunker
#       9 from src.embeddings import EmbeddingGenerator
#
# ...
